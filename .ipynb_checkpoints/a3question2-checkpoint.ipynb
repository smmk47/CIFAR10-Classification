# %%
# ============================================================
# Vision Transformer (ViT) for CIFAR-10 Image Classification
# ============================================================

# --------------------
# 1. Setup and Imports
# --------------------
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import time
import os

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
from torch.utils.data import DataLoader, random_split
from torchvision import datasets, transforms, models

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report

import torchvision

# Check if GPU is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f'Using device: {device}')

# -------------------------------
# 2. Data Preprocessing and Augmentation
# -------------------------------

# Define transformations for training and testing
train_transform = transforms.Compose([
    transforms.RandomCrop(32, padding=4),        # Random cropping with padding
    transforms.RandomHorizontalFlip(),           # Random horizontal flipping
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465),  # Normalize with CIFAR-10 mean and std
                         (0.2023, 0.1994, 0.2010)),
])

test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465),
                         (0.2023, 0.1994, 0.2010)),
])

# Load the CIFAR-10 datasets
train_dataset = datasets.CIFAR10(root='./data', train=True, download=True, transform=train_transform)
test_dataset = datasets.CIFAR10(root='./data', train=False, download=True, transform=test_transform)

# Create validation split from training data
train_size = int(0.8 * len(train_dataset))
val_size = len(train_dataset) - train_size
train_subset, val_subset = random_split(train_dataset, [train_size, val_size])

# Define data loaders
batch_size = 128

train_loader = DataLoader(train_subset, batch_size=batch_size, shuffle=True, num_workers=2)
val_loader = DataLoader(val_subset, batch_size=batch_size, shuffle=False, num_workers=2)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=2)

print(f'Training samples: {len(train_subset)}')
print(f'Validation samples: {len(val_subset)}')
print(f'Test samples: {len(test_dataset)}')

# -----------------------------
# 2.2 Visualizing Sample Images
# -----------------------------

# Function to show images
def imshow(img, title):
    img = img / 2 + 0.5  # Unnormalize
    npimg = img.numpy()
    plt.figure(figsize=(10,10))
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    if isinstance(title, list):
        title = ', '.join(title)
    plt.title(title)
    plt.axis('off')
    plt.show()

# Get some random training images
dataiter = iter(train_loader)
images, labels = next(dataiter)  # Corrected line

# Show images
imshow(torchvision.utils.make_grid(images[:16], nrow=4), title=[train_dataset.classes[label] for label in labels[:16]])

# -----------------------------
# 3. Vision Transformer (ViT) Implementation
# -----------------------------

class PatchEmbedding(nn.Module):
    def __init__(self, img_size=32, patch_size=4, in_channels=3, embed_dim=128):
        super(PatchEmbedding, self).__init__()
        self.patch_size = patch_size
        self.embed_dim = embed_dim
        self.num_patches = (img_size // patch_size) ** 2
        
        self.proj = nn.Conv2d(in_channels, embed_dim, kernel_size=patch_size, stride=patch_size)
    
    def forward(self, x):
        # x shape: (batch_size, in_channels, img_size, img_size)
        x = self.proj(x)  # shape: (batch_size, embed_dim, num_patches^(1/2), num_patches^(1/2))
        x = x.flatten(2)  # shape: (batch_size, embed_dim, num_patches)
        x = x.transpose(1, 2)  # shape: (batch_size, num_patches, embed_dim)
        return x

class VisionTransformer(nn.Module):
    def __init__(self, img_size=32, patch_size=4, in_channels=3, num_classes=10, 
                 embed_dim=128, depth=6, num_heads=8, mlp_dim=256, dropout=0.1):
        super(VisionTransformer, self).__init__()
        self.patch_embed = PatchEmbedding(img_size, patch_size, in_channels, embed_dim)
        num_patches = self.patch_embed.num_patches
        
        # Class token
        self.cls_token = nn.Parameter(torch.zeros(1, 1, embed_dim))
        
        # Positional encoding
        self.pos_embed = nn.Parameter(torch.zeros(1, num_patches + 1, embed_dim))
        self.dropout = nn.Dropout(dropout)
        
        # Transformer Encoder
        encoder_layer = nn.TransformerEncoderLayer(d_model=embed_dim, nhead=num_heads, 
                                                   dim_feedforward=mlp_dim, dropout=dropout)
        self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=depth)
        
        # Classification head
        self.mlp_head = nn.Sequential(
            nn.LayerNorm(embed_dim),
            nn.Linear(embed_dim, num_classes)
        )
        
        # Initialize weights
        self._init_weights()
    
    def _init_weights(self):
        nn.init.trunc_normal_(self.pos_embed, std=0.02)
        nn.init.trunc_normal_(self.cls_token, std=0.02)
        for m in self.modules():
            if isinstance(m, nn.Linear):
                nn.init.xavier_uniform_(m.weight)
                if m.bias is not None:
                    nn.init.zeros_(m.bias)
            elif isinstance(m, nn.LayerNorm):
                nn.init.zeros_(m.bias)
                nn.init.ones_(m.weight)
    
    def forward(self, x):
        batch_size = x.size(0)
        x = self.patch_embed(x)  # shape: (batch_size, num_patches, embed_dim)
        
        cls_tokens = self.cls_token.expand(batch_size, -1, -1)  # shape: (batch_size, 1, embed_dim)
        x = torch.cat((cls_tokens, x), dim=1)  # shape: (batch_size, num_patches +1, embed_dim)
        
        x = x + self.pos_embed  # Add positional encoding
        x = self.dropout(x)
        
        x = x.transpose(0,1)  # Transformer expects input shape: (seq_len, batch_size, embed_dim)
        x = self.transformer(x)  # shape: (seq_len, batch_size, embed_dim)
        x = x[0]  # Take the cls token output
        
        x = self.mlp_head(x)
        return x

# Instantiate the ViT model
vit_model = VisionTransformer(
    img_size=32,
    patch_size=4,
    in_channels=3,
    num_classes=10,
    embed_dim=128,
    depth=6,
    num_heads=8,
    mlp_dim=256,
    dropout=0.1
).to(device)

print(vit_model)

# -----------------------------
# 4. Hybrid CNN-MLP Architecture
# -----------------------------

class HybridCNNMLP(nn.Module):
    def __init__(self, img_size=32, patch_size=4, in_channels=3, num_classes=10, 
                 embed_dim=128, mlp_dim=256, dropout=0.1):
        super(HybridCNNMLP, self).__init__()
        self.patch_size = patch_size
        self.num_patches = (img_size // patch_size) ** 2
        
        self.cnn = nn.Sequential(
            nn.Conv2d(in_channels, embed_dim, kernel_size=patch_size, stride=patch_size),
            nn.ReLU(),
            nn.BatchNorm2d(embed_dim)
        )
        
        self.flatten = nn.Flatten(2)  # shape: (batch_size, embed_dim, num_patches)
        self.mlp = nn.Sequential(
            nn.Linear(embed_dim, mlp_dim),
            nn.ReLU(),
            nn.BatchNorm1d(mlp_dim),
            nn.Dropout(dropout),
            nn.Linear(mlp_dim, num_classes)
        )
    
    def forward(self, x):
        x = self.cnn(x)  # shape: (batch_size, embed_dim, num_patches^(1/2), num_patches^(1/2))
        x = self.flatten(x)  # shape: (batch_size, embed_dim, num_patches)
        x = x.mean(dim=2)  # Global average pooling over patches: (batch_size, embed_dim)
        x = self.mlp(x)  # Classification
        return x

# Instantiate the Hybrid CNN-MLP model
hybrid_model = HybridCNNMLP(
    img_size=32,
    patch_size=4,
    in_channels=3,
    num_classes=10,
    embed_dim=128,
    mlp_dim=256,
    dropout=0.1
).to(device)

print(hybrid_model)

# -----------------------------
# 5. ResNet with Transfer Learning
# -----------------------------

# Load a pretrained ResNet18 model
resnet_model = models.resnet18(pretrained=True)

# Freeze all layers
for param in resnet_model.parameters():
    param.requires_grad = False

# Modify the final fully connected layer
num_ftrs = resnet_model.fc.in_features
resnet_model.fc = nn.Sequential(
    nn.Linear(num_ftrs, 256),
    nn.ReLU(),
    nn.Dropout(0.4),
    nn.Linear(256, 10)
)

resnet_model = resnet_model.to(device)

print(resnet_model)

# -----------------------------
# 6. Training and Hyperparameter Tuning
# -----------------------------

def train_model(model, criterion, optimizer, scheduler, num_epochs=25, early_stopping_patience=5):
    since = time.time()
    
    best_model_wts = None
    best_acc = 0.0
    epochs_no_improve = 0
    
    train_acc_history = []
    val_acc_history = []
    train_loss_history = []
    val_loss_history = []
    
    for epoch in range(num_epochs):
        print(f'Epoch {epoch +1}/{num_epochs}')
        print('-' * 10)
        
        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()
                dataloader = train_loader
            else:
                model.eval()
                dataloader = val_loader
            
            running_loss = 0.0
            running_corrects = 0
            total_samples = 0
            
            # Iterate over data
            for inputs, labels in dataloader:
                inputs = inputs.to(device)
                labels = labels.to(device)
                
                # Zero the parameter gradients
                optimizer.zero_grad()
                
                # Forward
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)
                
                    # Backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()
                
                # Statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
                total_samples += inputs.size(0)
            
            epoch_loss = running_loss / total_samples
            epoch_acc = running_corrects.double() / total_samples
            
            if phase == 'train':
                train_acc_history.append(epoch_acc.item())
                train_loss_history.append(epoch_loss)
                scheduler.step()
            else:
                val_acc_history.append(epoch_acc.item())
                val_loss_history.append(epoch_loss)
            
            print(f'{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')
            
            # Deep copy the model
            if phase == 'val':
                if epoch_acc > best_acc:
                    best_acc = epoch_acc
                    best_model_wts = model.state_dict()
                    epochs_no_improve = 0
                else:
                    epochs_no_improve +=1
        
        # Early stopping
        if epochs_no_improve == early_stopping_patience:
            print('Early stopping!')
            break
        
        print()
    
    time_elapsed = time.time() - since
    print(f'Training complete in {time_elapsed //60:.0f}m {time_elapsed %60:.0f}s')
    print(f'Best val Acc: {best_acc:.4f}')
    
    # Load best model weights
    if best_model_wts is not None:
        model.load_state_dict(best_model_wts)
    
    history = {
        'train_acc': train_acc_history,
        'val_acc': val_acc_history,
        'train_loss': train_loss_history,
        'val_loss': val_loss_history
    }
    
    return model, history

# -----------------------------
# 6.2 Hyperparameter Setup for ViT
# -----------------------------

# Define optimizer for ViT
vit_optimizer = optim.Adam(vit_model.parameters(), lr=3e-4)

# Define scheduler linked to the above optimizer
vit_scheduler = lr_scheduler.StepLR(vit_optimizer, step_size=10, gamma=0.1)

# Define hyperparameters for ViT
vit_params = {
    'model': vit_model,
    'criterion': nn.CrossEntropyLoss(),
    'optimizer': vit_optimizer,
    'scheduler': vit_scheduler,
    'num_epochs': 50,
    'early_stopping_patience': 10
}

# -----------------------------
# 6.3 Training ViT
# -----------------------------

# Train the ViT model
print("Training Vision Transformer...")
vit_trained, vit_history = train_model(
    model=vit_params['model'],
    criterion=vit_params['criterion'],
    optimizer=vit_params['optimizer'],
    scheduler=vit_params['scheduler'],
    num_epochs=vit_params['num_epochs'],
    early_stopping_patience=vit_params['early_stopping_patience']
)

# -----------------------------
# 7. Evaluation Metrics and Visualization
# -----------------------------

def evaluate_model(model, dataloader):
    model.eval()
    all_preds = []
    all_labels = []
    
    with torch.no_grad():
        for inputs, labels in dataloader:
            inputs = inputs.to(device)
            labels = labels.to(device)
            
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
    
    accuracy = accuracy_score(all_labels, all_preds)
    precision = precision_score(all_labels, all_preds, average='macro', zero_division=0)
    recall = recall_score(all_labels, all_preds, average='macro', zero_division=0)
    f1 = f1_score(all_labels, all_preds, average='macro', zero_division=0)
    
    print(f'Accuracy: {accuracy:.4f}')
    print(f'Precision: {precision:.4f}')
    print(f'Recall: {recall:.4f}')
    print(f'F1-Score: {f1:.4f}')
    
    # Confusion Matrix
    cm = confusion_matrix(all_labels, all_preds)
    plt.figure(figsize=(10,8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
                xticklabels=test_dataset.classes, 
                yticklabels=test_dataset.classes)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    plt.show()
    
    # Classification Report
    print('Classification Report:')
    print(classification_report(all_labels, all_preds, target_names=test_dataset.classes, zero_division=0))
    
    return accuracy, precision, recall, f1, cm

# -----------------------------
# 7.2 Evaluating ViT on Test Set
# -----------------------------

# Evaluate ViT
print("\nEvaluating Vision Transformer on Test Set:")
vit_metrics = evaluate_model(vit_trained, test_loader)

# -----------------------------
# 8. Training Hybrid CNN-MLP Architecture
# -----------------------------

# Define optimizer for Hybrid Model
hybrid_optimizer = optim.Adam(hybrid_model.parameters(), lr=1e-3)

# Define scheduler linked to the above optimizer
hybrid_scheduler = lr_scheduler.StepLR(hybrid_optimizer, step_size=10, gamma=0.1)

# Define hyperparameters for Hybrid Model
hybrid_params = {
    'model': hybrid_model,
    'criterion': nn.CrossEntropyLoss(),
    'optimizer': hybrid_optimizer,
    'scheduler': hybrid_scheduler,
    'num_epochs': 50,
    'early_stopping_patience': 10
}

# -----------------------------
# 8.2 Training Hybrid Model
# -----------------------------

# Train the Hybrid CNN-MLP model
print("\nTraining Hybrid CNN-MLP Model...")
hybrid_trained, hybrid_history = train_model(
    model=hybrid_params['model'],
    criterion=hybrid_params['criterion'],
    optimizer=hybrid_params['optimizer'],
    scheduler=hybrid_params['scheduler'],
    num_epochs=hybrid_params['num_epochs'],
    early_stopping_patience=hybrid_params['early_stopping_patience']
)

# -----------------------------
# 8.3 Evaluating Hybrid Model on Test Set
# -----------------------------

# Evaluate Hybrid Model
print("\nEvaluating Hybrid CNN-MLP on Test Set:")
hybrid_metrics = evaluate_model(hybrid_trained, test_loader)

# -----------------------------
# 9. Training ResNet with Transfer Learning
# -----------------------------

# Optionally unfreeze some layers for fine-tuning
# Here, we freeze all layers except the last two layers
for name, param in resnet_model.named_parameters():
    if "fc" in name:
        param.requires_grad = True
    else:
        param.requires_grad = False

# Define optimizer for ResNet (only parameters of the classifier are being optimized)
resnet_optimizer = optim.Adam(resnet_model.fc.parameters(), lr=1e-3)

# Define scheduler linked to the above optimizer
resnet_scheduler = lr_scheduler.StepLR(resnet_optimizer, step_size=10, gamma=0.1)

# Define hyperparameters for ResNet
resnet_params = {
    'model': resnet_model,
    'criterion': nn.CrossEntropyLoss(),
    'optimizer': resnet_optimizer,
    'scheduler': resnet_scheduler,
    'num_epochs': 25,
    'early_stopping_patience': 5
}

# -----------------------------
# 9.3 Training ResNet
# -----------------------------

# Train the ResNet model
print("\nTraining ResNet with Transfer Learning...")
resnet_trained, resnet_history = train_model(
    model=resnet_params['model'],
    criterion=resnet_params['criterion'],
    optimizer=resnet_params['optimizer'],
    scheduler=resnet_params['scheduler'],
    num_epochs=resnet_params['num_epochs'],
    early_stopping_patience=resnet_params['early_stopping_patience']
)

# -----------------------------
# 9.4 Evaluating ResNet on Test Set
# -----------------------------

# Evaluate ResNet
print("\nEvaluating ResNet on Test Set:")
resnet_metrics = evaluate_model(resnet_trained, test_loader)

# -----------------------------
# 10. Performance Comparison
# -----------------------------

# Compile comparison metrics
comparison_df = pd.DataFrame({
    'Model': ['Vision Transformer', 'Hybrid CNN-MLP', 'ResNet'],
    'Accuracy': [vit_metrics[0], hybrid_metrics[0], resnet_metrics[0]],
    'Precision': [vit_metrics[1], hybrid_metrics[1], resnet_metrics[1]],
    'Recall': [vit_metrics[2], hybrid_metrics[2], resnet_metrics[2]],
    'F1-Score': [vit_metrics[3], hybrid_metrics[3], resnet_metrics[3]],
    # 'Training Time': [...],  # To be filled with actual times if recorded
    # 'Memory Usage': [...],   # To be filled with actual usage if recorded
    # 'Inference Speed': [...] # To be filled with actual speeds if recorded
})

print("\nPerformance Comparison:")
print(comparison_df)

# Plotting Accuracy Comparison
plt.figure(figsize=(8,6))
sns.barplot(x='Model', y='Accuracy', data=comparison_df)
plt.title('Model Accuracy Comparison')
plt.ylim(0,1)
plt.show()

# Plotting Precision Comparison
plt.figure(figsize=(8,6))
sns.barplot(x='Model', y='Precision', data=comparison_df)
plt.title('Model Precision Comparison')
plt.ylim(0,1)
plt.show()

# Plotting Recall Comparison
plt.figure(figsize=(8,6))
sns.barplot(x='Model', y='Recall', data=comparison_df)
plt.title('Model Recall Comparison')
plt.ylim(0,1)
plt.show()

# Plotting F1-Score Comparison
plt.figure(figsize=(8,6))
sns.barplot(x='Model', y='F1-Score', data=comparison_df)
plt.title('Model F1-Score Comparison')
plt.ylim(0,1)
plt.show()

# -----------------------------
# 11. Deployment and Result Visualization
# -----------------------------

# Function to visualize predictions
def visualize_predictions(model, dataloader, classes, num_images=16):
    model.eval()
    images_shown = 0
    plt.figure(figsize=(12,12))
    
    with torch.no_grad():
        for inputs, labels in dataloader:
            inputs = inputs.to(device)
            labels = labels.to(device)
            
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            
            for i in range(inputs.size(0)):
                if images_shown == num_images:
                    plt.show()
                    return
                images_shown +=1
                
                ax = plt.subplot(int(np.sqrt(num_images))+1, int(np.sqrt(num_images))+1, images_shown)
                img = inputs[i].cpu().numpy()
                # Unnormalize
                img = img * np.array([0.2023, 0.1994, 0.2010]).reshape(3,1,1) + np.array([0.4914, 0.4822, 0.4465]).reshape(3,1,1)
                img = np.clip(img, 0, 1)
                img = np.transpose(img, (1, 2, 0))
                plt.imshow(img)
                title_color = 'green' if preds[i] == labels[i] else 'red'
                plt.title(f'Pred: {classes[preds[i]]}\nTrue: {classes[labels[i]]}', color=title_color)
                plt.axis('off')
    plt.show()

# Visualize predictions for ViT
print("\nVision Transformer Predictions:")
visualize_predictions(vit_trained, test_loader, test_dataset.classes)

# Visualize predictions for Hybrid Model
print("\nHybrid CNN-MLP Predictions:")
visualize_predictions(hybrid_trained, test_loader, test_dataset.classes)

# Visualize predictions for ResNet
print("\nResNet Predictions:")
visualize_predictions(resnet_trained, test_loader, test_dataset.classes)

# -----------------------------
# 12. Training Curves
# -----------------------------

def plot_training_curves(history, model_name):
    epochs = range(1, len(history['train_acc']) +1)
    
    plt.figure(figsize=(14,5))
    
    # Accuracy
    plt.subplot(1,2,1)
    plt.plot(epochs, history['train_acc'], 'b-', label='Training Accuracy')
    plt.plot(epochs, history['val_acc'], 'r-', label='Validation Accuracy')
    plt.title(f'{model_name} Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    
    # Loss
    plt.subplot(1,2,2)
    plt.plot(epochs, history['train_loss'], 'b-', label='Training Loss')
    plt.plot(epochs, history['val_loss'], 'r-', label='Validation Loss')
    plt.title(f'{model_name} Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    
    plt.show()

# Plotting for ViT
print("\nTraining Curves for Vision Transformer:")
plot_training_curves(vit_history, 'Vision Transformer')

# Plotting for Hybrid Model
print("\nTraining Curves for Hybrid CNN-MLP:")
plot_training_curves(hybrid_history, 'Hybrid CNN-MLP')

# Plotting for ResNet
print("\nTraining Curves for ResNet:")
plot_training_curves(resnet_history, 'ResNet')

# -----------------------------
# 13. Conclusion and Report
# -----------------------------

# (This section is intended for a written report and does not contain executable code.)
# You can summarize your findings, methodology, challenges, and compare the strengths and weaknesses
# of each model based on the results obtained above.
# Out:
# Using device: cuda
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:03<00:00, 47821070.87it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
# Training samples: 40000
# Validation samples: 10000
# Test samples: 10000
# /opt/conda/lib/python3.10/site-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# VisionTransformer(
#   (patch_embed): PatchEmbedding(
#     (proj): Conv2d(3, 128, kernel_size=(4, 4), stride=(4, 4))
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (transformer): TransformerEncoder(
#     (layers): ModuleList(
#       (0-5): 6 x TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=128, out_features=128, bias=True)
#         )
#         (linear1): Linear(in_features=128, out_features=256, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=256, out_features=128, bias=True)
#         (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#       )
#     )
#   )
#   (mlp_head): Sequential(
#     (0): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=128, out_features=10, bias=True)
#   )
# )
# HybridCNNMLP(
#   (cnn): Sequential(
#     (0): Conv2d(3, 128, kernel_size=(4, 4), stride=(4, 4))
#     (1): ReLU()
#     (2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (flatten): Flatten(start_dim=2, end_dim=-1)
#   (mlp): Sequential(
#     (0): Linear(in_features=128, out_features=256, bias=True)
#     (1): ReLU()
#     (2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.1, inplace=False)
#     (4): Linear(in_features=256, out_features=10, bias=True)
#   )
# )
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 191MB/s]
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Sequential(
#     (0): Linear(in_features=512, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.4, inplace=False)
#     (3): Linear(in_features=256, out_features=10, bias=True)
#   )
# )
# Training Vision Transformer...
# Epoch 1/50
# ----------
# train Loss: 1.9759 Acc: 0.2595
# val Loss: 1.7038 Acc: 0.3593
#
# Epoch 2/50
# ----------
# train Loss: 1.7065 Acc: 0.3578
# val Loss: 1.5840 Acc: 0.4142
#
# Epoch 3/50
# ----------
# train Loss: 1.5569 Acc: 0.4201
# val Loss: 1.4496 Acc: 0.4688
#
# Epoch 4/50
# ----------
# train Loss: 1.4215 Acc: 0.4777
# val Loss: 1.3608 Acc: 0.5138
#
# Epoch 5/50
# ----------
# train Loss: 1.3262 Acc: 0.5172
# val Loss: 1.2914 Acc: 0.5359
#
# Epoch 6/50
# ----------
# train Loss: 1.2739 Acc: 0.5370
# val Loss: 1.2015 Acc: 0.5596
#
# Epoch 7/50
# ----------
# train Loss: 1.2191 Acc: 0.5580
# val Loss: 1.1524 Acc: 0.5845
#
# Epoch 8/50
# ----------
# train Loss: 1.1802 Acc: 0.5688
# val Loss: 1.1724 Acc: 0.5860
#
# Epoch 9/50
# ----------
# train Loss: 1.1487 Acc: 0.5844
# val Loss: 1.0745 Acc: 0.6121
#
# Epoch 10/50
# ----------
# train Loss: 1.1170 Acc: 0.5959
# val Loss: 1.1004 Acc: 0.6077
#
# Epoch 11/50
# ----------
# train Loss: 1.0355 Acc: 0.6249
# val Loss: 1.0137 Acc: 0.6355
#
# Epoch 12/50
# ----------
# train Loss: 1.0186 Acc: 0.6343
# val Loss: 1.0107 Acc: 0.6393
#
# Epoch 13/50
# ----------
# train Loss: 1.0060 Acc: 0.6346
# val Loss: 1.0080 Acc: 0.6377
#
# Epoch 14/50
# ----------
# train Loss: 0.9996 Acc: 0.6413
# val Loss: 0.9950 Acc: 0.6450
#
# Epoch 15/50
# ----------
# train Loss: 0.9930 Acc: 0.6418
# val Loss: 0.9858 Acc: 0.6420
#
# Epoch 16/50
# ----------
# train Loss: 0.9955 Acc: 0.6391
# val Loss: 0.9933 Acc: 0.6419
#
# Epoch 17/50
# ----------
# train Loss: 0.9823 Acc: 0.6460
# val Loss: 0.9912 Acc: 0.6475
#
# Epoch 18/50
# ----------
# train Loss: 0.9756 Acc: 0.6490
# val Loss: 0.9874 Acc: 0.6503
#
# Epoch 19/50
# ----------
# train Loss: 0.9749 Acc: 0.6498
# val Loss: 0.9848 Acc: 0.6486
#
# Epoch 20/50
# ----------
# train Loss: 0.9729 Acc: 0.6493
# val Loss: 0.9694 Acc: 0.6522
#
# Epoch 21/50
# ----------
# train Loss: 0.9602 Acc: 0.6541
# val Loss: 0.9737 Acc: 0.6545
#
# Epoch 22/50
# ----------
# train Loss: 0.9522 Acc: 0.6548
# val Loss: 0.9653 Acc: 0.6525
#
# Epoch 23/50
# ----------
# train Loss: 0.9523 Acc: 0.6567
# val Loss: 0.9765 Acc: 0.6517
#
# Epoch 24/50
# ----------
# train Loss: 0.9524 Acc: 0.6563
# val Loss: 0.9766 Acc: 0.6503
#
# Epoch 25/50
# ----------
# train Loss: 0.9537 Acc: 0.6589
# val Loss: 0.9732 Acc: 0.6552
#
# Epoch 26/50
# ----------
# train Loss: 0.9536 Acc: 0.6565
# val Loss: 0.9723 Acc: 0.6516
#
# Epoch 27/50
# ----------
# train Loss: 0.9516 Acc: 0.6566
# val Loss: 0.9777 Acc: 0.6494
#
# Epoch 28/50
# ----------
# train Loss: 0.9500 Acc: 0.6593
# val Loss: 0.9702 Acc: 0.6545
#
# Epoch 29/50
# ----------
# train Loss: 0.9504 Acc: 0.6571
# val Loss: 0.9746 Acc: 0.6602
#
# Epoch 30/50
# ----------
# train Loss: 0.9513 Acc: 0.6563
# val Loss: 0.9720 Acc: 0.6505
#
# Epoch 31/50
# ----------
# train Loss: 0.9499 Acc: 0.6555
# val Loss: 0.9781 Acc: 0.6487
#
# Epoch 32/50
# ----------
# train Loss: 0.9486 Acc: 0.6564
# val Loss: 0.9750 Acc: 0.6496
#
# Epoch 33/50
# ----------
# train Loss: 0.9454 Acc: 0.6602
# val Loss: 0.9687 Acc: 0.6547
#
# Epoch 34/50
# ----------
# train Loss: 0.9473 Acc: 0.6571
# val Loss: 0.9713 Acc: 0.6529
#
# Epoch 35/50
# ----------
# train Loss: 0.9518 Acc: 0.6574
# val Loss: 0.9745 Acc: 0.6487
#
# Epoch 36/50
# ----------
# train Loss: 0.9467 Acc: 0.6607
# val Loss: 0.9725 Acc: 0.6538
#
# Epoch 37/50
# ----------
# train Loss: 0.9435 Acc: 0.6602
# val Loss: 0.9627 Acc: 0.6567
#
# Epoch 38/50
# ----------
# train Loss: 0.9486 Acc: 0.6561
# val Loss: 0.9617 Acc: 0.6607
#
# Epoch 39/50
# ----------
# train Loss: 0.9486 Acc: 0.6592
# val Loss: 0.9813 Acc: 0.6528
#
# Epoch 40/50
# ----------
# train Loss: 0.9523 Acc: 0.6581
# val Loss: 0.9675 Acc: 0.6563
#
# Epoch 41/50
# ----------
# train Loss: 0.9480 Acc: 0.6570
# val Loss: 0.9630 Acc: 0.6533
#
# Epoch 42/50
# ----------
# train Loss: 0.9481 Acc: 0.6585
# val Loss: 0.9815 Acc: 0.6510
#
# Epoch 43/50
# ----------
# train Loss: 0.9486 Acc: 0.6583
# val Loss: 0.9599 Acc: 0.6555
#
# Epoch 44/50
# ----------
# train Loss: 0.9456 Acc: 0.6590
# val Loss: 0.9664 Acc: 0.6519
#
# Epoch 45/50
# ----------
# train Loss: 0.9512 Acc: 0.6577
# val Loss: 0.9680 Acc: 0.6482
#
# Epoch 46/50
# ----------
# train Loss: 0.9507 Acc: 0.6549
# val Loss: 0.9596 Acc: 0.6558
#
# Epoch 47/50
# ----------
# train Loss: 0.9492 Acc: 0.6554
# val Loss: 0.9741 Acc: 0.6540
#
# Epoch 48/50
# ----------
# train Loss: 0.9516 Acc: 0.6568
# val Loss: 0.9673 Acc: 0.6554
# Early stopping!
# Training complete in 13m 4s
# Best val Acc: 0.6607
#
# Evaluating Vision Transformer on Test Set:
# Accuracy: 0.6527
# Precision: 0.6553
# Recall: 0.6527
# F1-Score: 0.6490
# Classification Report:
#               precision    recall  f1-score   support
#
#     airplane       0.65      0.71      0.68      1000
#   automobile       0.74      0.78      0.76      1000
#         bird       0.55      0.54      0.55      1000
#          cat       0.52      0.33      0.40      1000
#         deer       0.65      0.54      0.59      1000
#          dog       0.49      0.70      0.58      1000
#         frog       0.76      0.70      0.73      1000
#        horse       0.66      0.72      0.69      1000
#         ship       0.78      0.80      0.79      1000
#        truck       0.75      0.69      0.72      1000
#
#     accuracy                           0.65     10000
#    macro avg       0.66      0.65      0.65     10000
# weighted avg       0.66      0.65      0.65     10000
#
#
# Training Hybrid CNN-MLP Model...
# Epoch 1/50
# ----------
# train Loss: 1.8652 Acc: 0.3050
# val Loss: 1.7974 Acc: 0.3343
#
# Epoch 2/50
# ----------
# train Loss: 1.7188 Acc: 0.3667
# val Loss: 1.6469 Acc: 0.3921
#
# Epoch 3/50
# ----------
# train Loss: 1.6353 Acc: 0.3984
# val Loss: 1.5839 Acc: 0.4120
#
# Epoch 4/50
# ----------
# train Loss: 1.5881 Acc: 0.4165
# val Loss: 1.5440 Acc: 0.4352
#
# Epoch 5/50
# ----------
# train Loss: 1.5598 Acc: 0.4278
# val Loss: 1.5282 Acc: 0.4417
#
# Epoch 6/50
# ----------
# train Loss: 1.5402 Acc: 0.4345
# val Loss: 1.5197 Acc: 0.4428
#
# Epoch 7/50
# ----------
# train Loss: 1.5177 Acc: 0.4449
# val Loss: 1.4776 Acc: 0.4636
#
# Epoch 8/50
# ----------
# train Loss: 1.5013 Acc: 0.4524
# val Loss: 1.5522 Acc: 0.4332
#
# Epoch 9/50
# ----------
# train Loss: 1.4901 Acc: 0.4553
# val Loss: 1.4873 Acc: 0.4508
#
# Epoch 10/50
# ----------
# train Loss: 1.4813 Acc: 0.4586
# val Loss: 1.4467 Acc: 0.4744
#
# Epoch 11/50
# ----------
# train Loss: 1.4180 Acc: 0.4833
# val Loss: 1.3837 Acc: 0.4941
#
# Epoch 12/50
# ----------
# train Loss: 1.4038 Acc: 0.4891
# val Loss: 1.3699 Acc: 0.5056
#
# Epoch 13/50
# ----------
# train Loss: 1.3929 Acc: 0.4948
# val Loss: 1.3821 Acc: 0.4995
#
# Epoch 14/50
# ----------
# train Loss: 1.3916 Acc: 0.4951
# val Loss: 1.3700 Acc: 0.5006
#
# Epoch 15/50
# ----------
# train Loss: 1.3820 Acc: 0.5006
# val Loss: 1.3533 Acc: 0.5101
#
# Epoch 16/50
# ----------
# train Loss: 1.3799 Acc: 0.5008
# val Loss: 1.3410 Acc: 0.5100
#
# Epoch 17/50
# ----------
# train Loss: 1.3750 Acc: 0.4995
# val Loss: 1.3581 Acc: 0.5079
#
# Epoch 18/50
# ----------
# train Loss: 1.3706 Acc: 0.5030
# val Loss: 1.3443 Acc: 0.5151
#
# Epoch 19/50
# ----------
# train Loss: 1.3698 Acc: 0.5032
# val Loss: 1.3499 Acc: 0.5096
#
# Epoch 20/50
# ----------
# train Loss: 1.3688 Acc: 0.5015
# val Loss: 1.3433 Acc: 0.5153
#
# Epoch 21/50
# ----------
# train Loss: 1.3586 Acc: 0.5086
# val Loss: 1.3397 Acc: 0.5129
#
# Epoch 22/50
# ----------
# train Loss: 1.3629 Acc: 0.5042
# val Loss: 1.3315 Acc: 0.5146
#
# Epoch 23/50
# ----------
# train Loss: 1.3591 Acc: 0.5086
# val Loss: 1.3228 Acc: 0.5229
#
# Epoch 24/50
# ----------
# train Loss: 1.3585 Acc: 0.5055
# val Loss: 1.3305 Acc: 0.5167
#
# Epoch 25/50
# ----------
# train Loss: 1.3574 Acc: 0.5065
# val Loss: 1.3394 Acc: 0.5131
#
# Epoch 26/50
# ----------
# train Loss: 1.3587 Acc: 0.5093
# val Loss: 1.3334 Acc: 0.5152
#
# Epoch 27/50
# ----------
# train Loss: 1.3524 Acc: 0.5099
# val Loss: 1.3386 Acc: 0.5147
#
# Epoch 28/50
# ----------
# train Loss: 1.3562 Acc: 0.5084
# val Loss: 1.3356 Acc: 0.5130
#
# Epoch 29/50
# ----------
# train Loss: 1.3547 Acc: 0.5077
# val Loss: 1.3421 Acc: 0.5164
#
# Epoch 30/50
# ----------
# train Loss: 1.3532 Acc: 0.5063
# val Loss: 1.3365 Acc: 0.5121
#
# Epoch 31/50
# ----------
# train Loss: 1.3553 Acc: 0.5048
# val Loss: 1.3366 Acc: 0.5195
#
# Epoch 32/50
# ----------
# train Loss: 1.3570 Acc: 0.5064
# val Loss: 1.3374 Acc: 0.5123
#
# Epoch 33/50
# ----------
# train Loss: 1.3537 Acc: 0.5086
# val Loss: 1.3318 Acc: 0.5220
# Early stopping!
# Training complete in 6m 17s
# Best val Acc: 0.5229
#
# Evaluating Hybrid CNN-MLP on Test Set:
# Accuracy: 0.4997
# Precision: 0.5011
# Recall: 0.4997
# F1-Score: 0.4936
# Classification Report:
#               precision    recall  f1-score   support
#
#     airplane       0.47      0.62      0.54      1000
#   automobile       0.55      0.54      0.55      1000
#         bird       0.40      0.38      0.39      1000
#          cat       0.37      0.21      0.27      1000
#         deer       0.50      0.43      0.46      1000
#          dog       0.40      0.59      0.48      1000
#         frog       0.54      0.66      0.59      1000
#        horse       0.57      0.51      0.54      1000
#         ship       0.60      0.58      0.59      1000
#        truck       0.60      0.47      0.53      1000
#
#     accuracy                           0.50     10000
#    macro avg       0.50      0.50      0.49     10000
# weighted avg       0.50      0.50      0.49     10000
#
#
# Training ResNet with Transfer Learning...
# Epoch 1/25
# ----------
# train Loss: 1.8546 Acc: 0.3356
# val Loss: 1.7011 Acc: 0.3935
#
# Epoch 2/25
# ----------
# train Loss: 1.7333 Acc: 0.3819
# val Loss: 1.6604 Acc: 0.4169
#
# Epoch 3/25
# ----------
# train Loss: 1.7107 Acc: 0.3921
# val Loss: 1.6414 Acc: 0.4123
#
# Epoch 4/25
# ----------
# train Loss: 1.6892 Acc: 0.3982
# val Loss: 1.6291 Acc: 0.4284
#
# Epoch 5/25
# ----------
# train Loss: 1.6795 Acc: 0.4026
# val Loss: 1.6291 Acc: 0.4162
#
# Epoch 6/25
# ----------
# train Loss: 1.6696 Acc: 0.4074
# val Loss: 1.6065 Acc: 0.4340
#
# Epoch 7/25
# ----------
# train Loss: 1.6657 Acc: 0.4066
# val Loss: 1.6059 Acc: 0.4348
#
# Epoch 8/25
# ----------
# train Loss: 1.6605 Acc: 0.4076
# val Loss: 1.5806 Acc: 0.4380
#
# Epoch 9/25
# ----------
# train Loss: 1.6473 Acc: 0.4140
# val Loss: 1.5836 Acc: 0.4431
#
# Epoch 10/25
# ----------
# train Loss: 1.6467 Acc: 0.4151
# val Loss: 1.5723 Acc: 0.4417
#
# Epoch 11/25
# ----------
# train Loss: 1.6168 Acc: 0.4304
# val Loss: 1.5629 Acc: 0.4469
#
# Epoch 12/25
# ----------
# train Loss: 1.6013 Acc: 0.4334
# val Loss: 1.5610 Acc: 0.4492
#
# Epoch 13/25
# ----------
# train Loss: 1.5973 Acc: 0.4343
# val Loss: 1.5538 Acc: 0.4485
#
# Epoch 14/25
# ----------
# train Loss: 1.6051 Acc: 0.4349
# val Loss: 1.5451 Acc: 0.4532
#
# Epoch 15/25
# ----------
# train Loss: 1.5909 Acc: 0.4374
# val Loss: 1.5553 Acc: 0.4533
#
# Epoch 16/25
# ----------
# train Loss: 1.5979 Acc: 0.4336
# val Loss: 1.5447 Acc: 0.4567
#
# Epoch 17/25
# ----------
# train Loss: 1.5956 Acc: 0.4334
# val Loss: 1.5379 Acc: 0.4614
#
# Epoch 18/25
# ----------
# train Loss: 1.5994 Acc: 0.4356
# val Loss: 1.5472 Acc: 0.4595
#
# Epoch 19/25
# ----------
# train Loss: 1.5876 Acc: 0.4399
# val Loss: 1.5425 Acc: 0.4603
#
# Epoch 20/25
# ----------
# train Loss: 1.5833 Acc: 0.4396
# val Loss: 1.5432 Acc: 0.4535
#
# Epoch 21/25
# ----------
# train Loss: 1.5799 Acc: 0.4425
# val Loss: 1.5348 Acc: 0.4596
#
# Epoch 22/25
# ----------
# train Loss: 1.5857 Acc: 0.4414
# val Loss: 1.5512 Acc: 0.4523
# Early stopping!
# Training complete in 4m 25s
# Best val Acc: 0.4614
#
# Evaluating ResNet on Test Set:
# Accuracy: 0.4489
# Precision: 0.4515
# Recall: 0.4489
# F1-Score: 0.4460
# Classification Report:
#               precision    recall  f1-score   support
#
#     airplane       0.42      0.58      0.49      1000
#   automobile       0.52      0.48      0.50      1000
#         bird       0.39      0.38      0.38      1000
#          cat       0.40      0.30      0.34      1000
#         deer       0.45      0.46      0.46      1000
#          dog       0.39      0.45      0.41      1000
#         frog       0.49      0.59      0.54      1000
#        horse       0.49      0.45      0.47      1000
#         ship       0.45      0.44      0.45      1000
#        truck       0.51      0.36      0.42      1000
#
#     accuracy                           0.45     10000
#    macro avg       0.45      0.45      0.45     10000
# weighted avg       0.45      0.45      0.45     10000
#
#
# Performance Comparison:
#                 Model  Accuracy  Precision  Recall  F1-Score
# 0  Vision Transformer    0.6527   0.655318  0.6527  0.648996
# 1      Hybrid CNN-MLP    0.4997   0.501083  0.4997  0.493561
# 2              ResNet    0.4489   0.451496  0.4489  0.445988
# Vision Transformer Predictions:
# Hybrid CNN-MLP Predictions:
# ResNet Predictions:
# Training Curves for Vision Transformer:
# Training Curves for Hybrid CNN-MLP:
# Training Curves for ResNet:

# %%
# ============================================================
# Vision Transformer (ViT), Hybrid CNN-MLP, and ResNet for CIFAR-10
# ============================================================

# --------------------
# 1. Setup and Imports
# --------------------
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import time
import os
import copy

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
from torch.utils.data import DataLoader, random_split
from torchvision import datasets, transforms, models

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report

import torchvision

# Set random seed for reproducibility
seed = 42
torch.manual_seed(seed)
np.random.seed(seed)

# Check if GPU is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f'Using device: {device}')

# -------------------------------
# 2. Data Preprocessing and Augmentation
# -------------------------------

# Define transformations for training and testing
train_transform = transforms.Compose([
    transforms.RandomCrop(32, padding=4),        # Random cropping with padding
    transforms.RandomHorizontalFlip(),           # Random horizontal flipping
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465),  # Normalize with CIFAR-10 mean and std
                         (0.2023, 0.1994, 0.2010)),
])

test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465),
                         (0.2023, 0.1994, 0.2010)),
])

# Load the CIFAR-10 datasets
train_dataset = datasets.CIFAR10(root='./data', train=True, download=True, transform=train_transform)
test_dataset = datasets.CIFAR10(root='./data', train=False, download=True, transform=test_transform)

# Create validation split from training data
train_size = int(0.8 * len(train_dataset))
val_size = len(train_dataset) - train_size
train_subset, val_subset = random_split(train_dataset, [train_size, val_size])

# Define data loaders
batch_size = 128

train_loader = DataLoader(train_subset, batch_size=batch_size, shuffle=True, num_workers=4, pin_memory=True)
val_loader = DataLoader(val_subset, batch_size=batch_size, shuffle=False, num_workers=4, pin_memory=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=4, pin_memory=True)

print(f'Training samples: {len(train_subset)}')
print(f'Validation samples: {len(val_subset)}')
print(f'Test samples: {len(test_dataset)}')

# -----------------------------
# 2.1 Visualizing Sample Images
# -----------------------------

# Function to show images
def imshow(img, title):
    img = img / 2 + 0.5  # Unnormalize
    npimg = img.numpy()
    plt.figure(figsize=(10,10))
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    if isinstance(title, list):
        title = ', '.join(title)
    plt.title(title)
    plt.axis('off')
    plt.show()

# Get some random training images
dataiter = iter(train_loader)
images, labels = next(dataiter)  # Corrected line

# Show images
imshow(torchvision.utils.make_grid(images[:16], nrow=4), title=[train_dataset.classes[label] for label in labels[:16]])

# -----------------------------
# 3. Vision Transformer (ViT) Implementation
# -----------------------------

class PatchEmbedding(nn.Module):
    def __init__(self, img_size=32, patch_size=4, in_channels=3, embed_dim=128):
        super(PatchEmbedding, self).__init__()
        self.patch_size = patch_size
        self.embed_dim = embed_dim
        self.num_patches = (img_size // patch_size) ** 2
        
        self.proj = nn.Conv2d(in_channels, embed_dim, kernel_size=patch_size, stride=patch_size)
    
    def forward(self, x):
        # x shape: (batch_size, in_channels, img_size, img_size)
        x = self.proj(x)  # shape: (batch_size, embed_dim, num_patches^(1/2), num_patches^(1/2))
        x = x.flatten(2)  # shape: (batch_size, embed_dim, num_patches)
        x = x.transpose(1, 2)  # shape: (batch_size, num_patches, embed_dim)
        return x

class VisionTransformer(nn.Module):
    def __init__(self, img_size=32, patch_size=4, in_channels=3, num_classes=10, 
                 embed_dim=128, depth=6, num_heads=8, mlp_dim=256, dropout=0.1):
        super(VisionTransformer, self).__init__()
        self.patch_embed = PatchEmbedding(img_size, patch_size, in_channels, embed_dim)
        num_patches = self.patch_embed.num_patches
        
        # Class token
        self.cls_token = nn.Parameter(torch.zeros(1, 1, embed_dim))
        
        # Positional encoding
        self.pos_embed = nn.Parameter(torch.zeros(1, num_patches + 1, embed_dim))
        self.dropout = nn.Dropout(dropout)
        
        # Transformer Encoder
        encoder_layer = nn.TransformerEncoderLayer(d_model=embed_dim, nhead=num_heads, 
                                                   dim_feedforward=mlp_dim, dropout=dropout)
        self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=depth)
        
        # Classification head
        self.mlp_head = nn.Sequential(
            nn.LayerNorm(embed_dim),
            nn.Linear(embed_dim, num_classes)
        )
        
        # Initialize weights
        self._init_weights()
    
    def _init_weights(self):
        nn.init.trunc_normal_(self.pos_embed, std=0.02)
        nn.init.trunc_normal_(self.cls_token, std=0.02)
        for m in self.modules():
            if isinstance(m, nn.Linear):
                nn.init.xavier_uniform_(m.weight)
                if m.bias is not None:
                    nn.init.zeros_(m.bias)
            elif isinstance(m, nn.LayerNorm):
                nn.init.zeros_(m.bias)
                nn.init.ones_(m.weight)
    
    def forward(self, x):
        batch_size = x.size(0)
        x = self.patch_embed(x)  # shape: (batch_size, num_patches, embed_dim)
        
        cls_tokens = self.cls_token.expand(batch_size, -1, -1)  # shape: (batch_size, 1, embed_dim)
        x = torch.cat((cls_tokens, x), dim=1)  # shape: (batch_size, num_patches +1, embed_dim)
        
        x = x + self.pos_embed  # Add positional encoding
        x = self.dropout(x)
        
        x = x.transpose(0,1)  # Transformer expects input shape: (seq_len, batch_size, embed_dim)
        x = self.transformer(x)  # shape: (seq_len, batch_size, embed_dim)
        x = x[0]  # Take the cls token output
        
        x = self.mlp_head(x)
        return x

# Instantiate the ViT model
vit_model = VisionTransformer(
    img_size=32,
    patch_size=4,
    in_channels=3,
    num_classes=10,
    embed_dim=128,
    depth=6,
    num_heads=8,
    mlp_dim=256,
    dropout=0.1
).to(device)

print("\nVision Transformer Model:")
print(vit_model)

# -----------------------------
# 4. Hybrid CNN-MLP Architecture
# -----------------------------

class HybridCNNMLP(nn.Module):
    def __init__(self, img_size=32, patch_size=4, in_channels=3, num_classes=10, 
                 embed_dim=128, mlp_dim=256, dropout=0.1):
        super(HybridCNNMLP, self).__init__()
        self.patch_size = patch_size
        self.num_patches = (img_size // patch_size) ** 2
        
        self.cnn = nn.Sequential(
            nn.Conv2d(in_channels, embed_dim, kernel_size=patch_size, stride=patch_size),
            nn.ReLU(),
            nn.BatchNorm2d(embed_dim)
        )
        
        self.flatten = nn.Flatten(2)  # shape: (batch_size, embed_dim, num_patches)
        self.mlp = nn.Sequential(
            nn.Linear(embed_dim, mlp_dim),
            nn.ReLU(),
            nn.BatchNorm1d(mlp_dim),
            nn.Dropout(dropout),
            nn.Linear(mlp_dim, num_classes)
        )
    
    def forward(self, x):
        x = self.cnn(x)  # shape: (batch_size, embed_dim, num_patches^(1/2), num_patches^(1/2))
        x = self.flatten(x)  # shape: (batch_size, embed_dim, num_patches)
        x = x.mean(dim=2)  # Global average pooling over patches: (batch_size, embed_dim)
        x = self.mlp(x)  # Classification
        return x

# Instantiate the Hybrid CNN-MLP model
hybrid_model = HybridCNNMLP(
    img_size=32,
    patch_size=4,
    in_channels=3,
    num_classes=10,
    embed_dim=128,
    mlp_dim=256,
    dropout=0.1
).to(device)

print("\nHybrid CNN-MLP Model:")
print(hybrid_model)

# -----------------------------
# 5. ResNet with Transfer Learning
# -----------------------------

# Load a pretrained ResNet18 model
resnet_model = models.resnet18(pretrained=True)

# Freeze all layers
for param in resnet_model.parameters():
    param.requires_grad = False

# Modify the final fully connected layer
num_ftrs = resnet_model.fc.in_features
resnet_model.fc = nn.Sequential(
    nn.Linear(num_ftrs, 256),
    nn.ReLU(),
    nn.Dropout(0.4),
    nn.Linear(256, 10)
)

resnet_model = resnet_model.to(device)

print("\nResNet18 Model with Transfer Learning:")
print(resnet_model)

# -----------------------------
# 6. Training and Hyperparameter Tuning
# -----------------------------

def train_model(model, criterion, optimizer, scheduler, num_epochs=25, early_stopping_patience=5):
    since = time.time()
    
    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0
    epochs_no_improve = 0
    
    train_acc_history = []
    val_acc_history = []
    train_loss_history = []
    val_loss_history = []
    
    for epoch in range(num_epochs):
        print(f'Epoch {epoch +1}/{num_epochs}')
        print('-' * 10)
        
        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()
                dataloader = train_loader
            else:
                model.eval()
                dataloader = val_loader
            
            running_loss = 0.0
            running_corrects = 0
            total_samples = 0
            
            # Iterate over data
            for inputs, labels in dataloader:
                inputs = inputs.to(device, non_blocking=True)
                labels = labels.to(device, non_blocking=True)
                
                # Zero the parameter gradients
                optimizer.zero_grad()
                
                # Forward
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)
                
                    # Backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()
                
                # Statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
                total_samples += inputs.size(0)
            
            epoch_loss = running_loss / total_samples
            epoch_acc = running_corrects.double() / total_samples
            
            if phase == 'train':
                train_acc_history.append(epoch_acc.item())
                train_loss_history.append(epoch_loss)
                scheduler.step()
            else:
                val_acc_history.append(epoch_acc.item())
                val_loss_history.append(epoch_loss)
            
            print(f'{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')
            
            # Deep copy the model
            if phase == 'val':
                if epoch_acc > best_acc:
                    best_acc = epoch_acc
                    best_model_wts = copy.deepcopy(model.state_dict())
                    epochs_no_improve = 0
                else:
                    epochs_no_improve +=1
        
        # Early stopping
        if epochs_no_improve == early_stopping_patience:
            print('Early stopping!')
            break
        
        print()
    
    time_elapsed = time.time() - since
    print(f'Training complete in {time_elapsed //60:.0f}m {time_elapsed %60:.0f}s')
    print(f'Best val Acc: {best_acc:.4f}')
    
    # Load best model weights
    model.load_state_dict(best_model_wts)
    
    history = {
        'train_acc': train_acc_history,
        'val_acc': val_acc_history,
        'train_loss': train_loss_history,
        'val_loss': val_loss_history
    }
    
    return model, history, time_elapsed

# -----------------------------
# 6.1 Training Vision Transformer (ViT)
# -----------------------------

# Define optimizer for ViT
vit_optimizer = optim.Adam(vit_model.parameters(), lr=3e-4)

# Define scheduler linked to the above optimizer
vit_scheduler = lr_scheduler.StepLR(vit_optimizer, step_size=20, gamma=0.1)

# Define hyperparameters for ViT
vit_params = {
    'model': vit_model,
    'criterion': nn.CrossEntropyLoss(),
    'optimizer': vit_optimizer,
    'scheduler': vit_scheduler,
    'num_epochs': 50,
    'early_stopping_patience': 10
}

# Train the ViT model
print("\nTraining Vision Transformer...")
vit_trained, vit_history, vit_training_time = train_model(
    model=vit_params['model'],
    criterion=vit_params['criterion'],
    optimizer=vit_params['optimizer'],
    scheduler=vit_params['scheduler'],
    num_epochs=vit_params['num_epochs'],
    early_stopping_patience=vit_params['early_stopping_patience']
)

# Save the trained ViT model
torch.save(vit_trained.state_dict(), 'vit_cifar10.pth')
print("Vision Transformer model saved as 'vit_cifar10.pth'")

# -----------------------------
# 7. Evaluation Metrics and Visualization
# -----------------------------

def evaluate_model(model, dataloader, classes):
    model.eval()
    all_preds = []
    all_labels = []
    
    with torch.no_grad():
        for inputs, labels in dataloader:
            inputs = inputs.to(device, non_blocking=True)
            labels = labels.to(device, non_blocking=True)
            
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
    
    accuracy = accuracy_score(all_labels, all_preds)
    precision = precision_score(all_labels, all_preds, average='macro', zero_division=0)
    recall = recall_score(all_labels, all_preds, average='macro', zero_division=0)
    f1 = f1_score(all_labels, all_preds, average='macro', zero_division=0)
    
    print(f'Accuracy: {accuracy:.4f}')
    print(f'Precision: {precision:.4f}')
    print(f'Recall: {recall:.4f}')
    print(f'F1-Score: {f1:.4f}')
    
    # Confusion Matrix
    cm = confusion_matrix(all_labels, all_preds)
    plt.figure(figsize=(10,8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
                xticklabels=classes, 
                yticklabels=classes)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    plt.show()
    
    # Classification Report
    print('Classification Report:')
    print(classification_report(all_labels, all_preds, target_names=classes, zero_division=0))
    
    return accuracy, precision, recall, f1, cm

# -----------------------------
# 7.1 Evaluating ViT on Test Set
# -----------------------------

# Evaluate ViT
print("\nEvaluating Vision Transformer on Test Set:")
vit_metrics = evaluate_model(vit_trained, test_loader, test_dataset.classes)

# -----------------------------
# 8. Training Hybrid CNN-MLP Architecture
# -----------------------------

# Define optimizer for Hybrid Model
hybrid_optimizer = optim.Adam(hybrid_model.parameters(), lr=1e-3)

# Define scheduler linked to the above optimizer
hybrid_scheduler = lr_scheduler.StepLR(hybrid_optimizer, step_size=20, gamma=0.1)

# Define hyperparameters for Hybrid Model
hybrid_params = {
    'model': hybrid_model,
    'criterion': nn.CrossEntropyLoss(),
    'optimizer': hybrid_optimizer,
    'scheduler': hybrid_scheduler,
    'num_epochs': 50,
    'early_stopping_patience': 10
}

# Train the Hybrid CNN-MLP model
print("\nTraining Hybrid CNN-MLP Model...")
hybrid_trained, hybrid_history, hybrid_training_time = train_model(
    model=hybrid_params['model'],
    criterion=hybrid_params['criterion'],
    optimizer=hybrid_params['optimizer'],
    scheduler=hybrid_params['scheduler'],
    num_epochs=hybrid_params['num_epochs'],
    early_stopping_patience=hybrid_params['early_stopping_patience']
)

# Save the trained Hybrid model
torch.save(hybrid_trained.state_dict(), 'hybrid_cifar10.pth')
print("Hybrid CNN-MLP model saved as 'hybrid_cifar10.pth'")

# -----------------------------
# 8.1 Evaluating Hybrid Model on Test Set
# -----------------------------

# Evaluate Hybrid Model
print("\nEvaluating Hybrid CNN-MLP on Test Set:")
hybrid_metrics = evaluate_model(hybrid_trained, test_loader, test_dataset.classes)

# -----------------------------
# 9. Training ResNet with Transfer Learning
# -----------------------------

# Optionally unfreeze some layers for fine-tuning
# Here, we freeze all layers except the last two layers of the classifier
for name, param in resnet_model.named_parameters():
    if "fc" in name:
        param.requires_grad = True
    else:
        param.requires_grad = False

# Define optimizer for ResNet (only parameters of the classifier are being optimized)
resnet_optimizer = optim.Adam(resnet_model.fc.parameters(), lr=1e-3)

# Define scheduler linked to the above optimizer
resnet_scheduler = lr_scheduler.StepLR(resnet_optimizer, step_size=10, gamma=0.1)

# Define hyperparameters for ResNet
resnet_params = {
    'model': resnet_model,
    'criterion': nn.CrossEntropyLoss(),
    'optimizer': resnet_optimizer,
    'scheduler': resnet_scheduler,
    'num_epochs': 25,
    'early_stopping_patience': 5
}

# Train the ResNet model
print("\nTraining ResNet with Transfer Learning...")
resnet_trained, resnet_history, resnet_training_time = train_model(
    model=resnet_params['model'],
    criterion=resnet_params['criterion'],
    optimizer=resnet_params['optimizer'],
    scheduler=resnet_params['scheduler'],
    num_epochs=resnet_params['num_epochs'],
    early_stopping_patience=resnet_params['early_stopping_patience']
)

# Save the trained ResNet model
torch.save(resnet_trained.state_dict(), 'resnet_cifar10.pth')
print("ResNet model saved as 'resnet_cifar10.pth'")

# -----------------------------
# 9.1 Evaluating ResNet on Test Set
# -----------------------------

# Evaluate ResNet
print("\nEvaluating ResNet on Test Set:")
resnet_metrics = evaluate_model(resnet_trained, test_loader, test_dataset.classes)

# -----------------------------
# 10. Performance Comparison
# -----------------------------

# Compile comparison metrics
comparison_df = pd.DataFrame({
    'Model': ['Vision Transformer', 'Hybrid CNN-MLP', 'ResNet'],
    'Accuracy': [vit_metrics[0], hybrid_metrics[0], resnet_metrics[0]],
    'Precision': [vit_metrics[1], hybrid_metrics[1], resnet_metrics[1]],
    'Recall': [vit_metrics[2], hybrid_metrics[2], resnet_metrics[2]],
    'F1-Score': [vit_metrics[3], hybrid_metrics[3], resnet_metrics[3]],
    'Training Time (s)': [vit_training_time, hybrid_training_time, resnet_training_time],
    # 'Memory Usage': [...],  # To be filled with actual usage if recorded
    # 'Inference Speed': [...] # To be filled with actual speeds if recorded
})

print("\nPerformance Comparison:")
print(comparison_df)

# Plotting Accuracy Comparison
plt.figure(figsize=(8,6))
sns.barplot(x='Model', y='Accuracy', data=comparison_df)
plt.title('Model Accuracy Comparison')
plt.ylim(0,1)
plt.show()

# Plotting Precision Comparison
plt.figure(figsize=(8,6))
sns.barplot(x='Model', y='Precision', data=comparison_df)
plt.title('Model Precision Comparison')
plt.ylim(0,1)
plt.show()

# Plotting Recall Comparison
plt.figure(figsize=(8,6))
sns.barplot(x='Model', y='Recall', data=comparison_df)
plt.title('Model Recall Comparison')
plt.ylim(0,1)
plt.show()

# Plotting F1-Score Comparison
plt.figure(figsize=(8,6))
sns.barplot(x='Model', y='F1-Score', data=comparison_df)
plt.title('Model F1-Score Comparison')
plt.ylim(0,1)
plt.show()

# -----------------------------
# 11. Training Curves Visualization
# -----------------------------

def plot_training_curves(history, model_name):
    epochs = range(1, len(history['train_acc']) +1)
    
    plt.figure(figsize=(14,5))
    
    # Accuracy
    plt.subplot(1,2,1)
    plt.plot(epochs, history['train_acc'], 'b-', label='Training Accuracy')
    plt.plot(epochs, history['val_acc'], 'r-', label='Validation Accuracy')
    plt.title(f'{model_name} Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    
    # Loss
    plt.subplot(1,2,2)
    plt.plot(epochs, history['train_loss'], 'b-', label='Training Loss')
    plt.plot(epochs, history['val_loss'], 'r-', label='Validation Loss')
    plt.title(f'{model_name} Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    
    plt.show()

# Plotting for ViT
print("\nTraining Curves for Vision Transformer:")
plot_training_curves(vit_history, 'Vision Transformer')

# Plotting for Hybrid Model
print("\nTraining Curves for Hybrid CNN-MLP:")
plot_training_curves(hybrid_history, 'Hybrid CNN-MLP')

# Plotting for ResNet
print("\nTraining Curves for ResNet:")
plot_training_curves(resnet_history, 'ResNet')

# -----------------------------
# 12. Saving Comparison Metrics
# -----------------------------

# Save the comparison metrics to a CSV file
comparison_df.to_csv('model_comparison.csv', index=False)
print("Model comparison metrics saved as 'model_comparison.csv'")
# Out:
# Using device: cuda
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:04<00:00, 35157724.66it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
# Training samples: 40000
# Validation samples: 10000
# Test samples: 10000
# /opt/conda/lib/python3.10/site-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Vision Transformer Model:
# VisionTransformer(
#   (patch_embed): PatchEmbedding(
#     (proj): Conv2d(3, 128, kernel_size=(4, 4), stride=(4, 4))
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (transformer): TransformerEncoder(
#     (layers): ModuleList(
#       (0-5): 6 x TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=128, out_features=128, bias=True)
#         )
#         (linear1): Linear(in_features=128, out_features=256, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=256, out_features=128, bias=True)
#         (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#       )
#     )
#   )
#   (mlp_head): Sequential(
#     (0): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=128, out_features=10, bias=True)
#   )
# )
#
# Hybrid CNN-MLP Model:
# HybridCNNMLP(
#   (cnn): Sequential(
#     (0): Conv2d(3, 128, kernel_size=(4, 4), stride=(4, 4))
#     (1): ReLU()
#     (2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (flatten): Flatten(start_dim=2, end_dim=-1)
#   (mlp): Sequential(
#     (0): Linear(in_features=128, out_features=256, bias=True)
#     (1): ReLU()
#     (2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.1, inplace=False)
#     (4): Linear(in_features=256, out_features=10, bias=True)
#   )
# )
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 73.1MB/s]
# ResNet18 Model with Transfer Learning:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Sequential(
#     (0): Linear(in_features=512, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.4, inplace=False)
#     (3): Linear(in_features=256, out_features=10, bias=True)
#   )
# )
#
# Training Vision Transformer...
# Epoch 1/50
# ----------
# train Loss: 1.9873 Acc: 0.2567
# val Loss: 1.7641 Acc: 0.3289
#
# Epoch 2/50
# ----------
# train Loss: 1.7212 Acc: 0.3505
# val Loss: 1.6127 Acc: 0.4114
#
# Epoch 3/50
# ----------
# train Loss: 1.5600 Acc: 0.4220
# val Loss: 1.4502 Acc: 0.4735
#
# Epoch 4/50
# ----------
# train Loss: 1.4270 Acc: 0.4799
# val Loss: 1.3868 Acc: 0.5037
#
# Epoch 5/50
# ----------
# train Loss: 1.3288 Acc: 0.5162
# val Loss: 1.3063 Acc: 0.5325
#
# Epoch 6/50
# ----------
# train Loss: 1.2643 Acc: 0.5392
# val Loss: 1.2001 Acc: 0.5766
#
# Epoch 7/50
# ----------
# train Loss: 1.2151 Acc: 0.5584
# val Loss: 1.1466 Acc: 0.5847
#
# Epoch 8/50
# ----------
# train Loss: 1.1708 Acc: 0.5750
# val Loss: 1.1309 Acc: 0.5981
#
# Epoch 9/50
# ----------
# train Loss: 1.1368 Acc: 0.5895
# val Loss: 1.0797 Acc: 0.6171
#
# Epoch 10/50
# ----------
# train Loss: 1.1045 Acc: 0.5999
# val Loss: 1.0694 Acc: 0.6183
#
# Epoch 11/50
# ----------
# train Loss: 1.0769 Acc: 0.6088
# val Loss: 1.0423 Acc: 0.6249
#
# Epoch 12/50
# ----------
# train Loss: 1.0492 Acc: 0.6208
# val Loss: 0.9822 Acc: 0.6568
#
# Epoch 13/50
# ----------
# train Loss: 1.0239 Acc: 0.6313
# val Loss: 0.9897 Acc: 0.6496
#
# Epoch 14/50
# ----------
# train Loss: 0.9972 Acc: 0.6411
# val Loss: 1.0251 Acc: 0.6349
#
# Epoch 15/50
# ----------
# train Loss: 0.9860 Acc: 0.6467
# val Loss: 0.9359 Acc: 0.6667
#
# Epoch 16/50
# ----------
# train Loss: 0.9538 Acc: 0.6567
# val Loss: 0.9297 Acc: 0.6703
#
# Epoch 17/50
# ----------
# train Loss: 0.9400 Acc: 0.6652
# val Loss: 0.9113 Acc: 0.6786
#
# Epoch 18/50
# ----------
# train Loss: 0.9213 Acc: 0.6705
# val Loss: 0.8991 Acc: 0.6849
#
# Epoch 19/50
# ----------
# train Loss: 0.9015 Acc: 0.6757
# val Loss: 0.8919 Acc: 0.6875
#
# Epoch 20/50
# ----------
# train Loss: 0.8818 Acc: 0.6867
# val Loss: 0.9342 Acc: 0.6804
#
# Epoch 21/50
# ----------
# train Loss: 0.7981 Acc: 0.7138
# val Loss: 0.8260 Acc: 0.7128
#
# Epoch 22/50
# ----------
# train Loss: 0.7804 Acc: 0.7229
# val Loss: 0.8305 Acc: 0.7119
#
# Epoch 23/50
# ----------
# train Loss: 0.7768 Acc: 0.7213
# val Loss: 0.8313 Acc: 0.7119
#
# Epoch 24/50
# ----------
# train Loss: 0.7701 Acc: 0.7254
# val Loss: 0.8265 Acc: 0.7159
#
# Epoch 25/50
# ----------
# train Loss: 0.7681 Acc: 0.7260
# val Loss: 0.8069 Acc: 0.7194
#
# Epoch 26/50
# ----------
# train Loss: 0.7611 Acc: 0.7281
# val Loss: 0.8095 Acc: 0.7198
#
# Epoch 27/50
# ----------
# train Loss: 0.7602 Acc: 0.7265
# val Loss: 0.8106 Acc: 0.7227
#
# Epoch 28/50
# ----------
# train Loss: 0.7571 Acc: 0.7287
# val Loss: 0.8116 Acc: 0.7206
#
# Epoch 29/50
# ----------
# train Loss: 0.7518 Acc: 0.7326
# val Loss: 0.7978 Acc: 0.7260
#
# Epoch 30/50
# ----------
# train Loss: 0.7505 Acc: 0.7305
# val Loss: 0.7962 Acc: 0.7242
#
# Epoch 31/50
# ----------
# train Loss: 0.7437 Acc: 0.7322
# val Loss: 0.8098 Acc: 0.7213
#
# Epoch 32/50
# ----------
# train Loss: 0.7412 Acc: 0.7344
# val Loss: 0.7944 Acc: 0.7253
#
# Epoch 33/50
# ----------
# train Loss: 0.7374 Acc: 0.7354
# val Loss: 0.7991 Acc: 0.7248
#
# Epoch 34/50
# ----------
# train Loss: 0.7431 Acc: 0.7339
# val Loss: 0.8086 Acc: 0.7239
#
# Epoch 35/50
# ----------
# train Loss: 0.7334 Acc: 0.7378
# val Loss: 0.8151 Acc: 0.7201
#
# Epoch 36/50
# ----------
# train Loss: 0.7288 Acc: 0.7401
# val Loss: 0.7872 Acc: 0.7305
#
# Epoch 37/50
# ----------
# train Loss: 0.7315 Acc: 0.7373
# val Loss: 0.7913 Acc: 0.7267
#
# Epoch 38/50
# ----------
# train Loss: 0.7251 Acc: 0.7395
# val Loss: 0.7877 Acc: 0.7274
#
# Epoch 39/50
# ----------
# train Loss: 0.7178 Acc: 0.7426
# val Loss: 0.7898 Acc: 0.7262
#
# Epoch 40/50
# ----------
# train Loss: 0.7180 Acc: 0.7424
# val Loss: 0.7863 Acc: 0.7300
#
# Epoch 41/50
# ----------
# train Loss: 0.7083 Acc: 0.7459
# val Loss: 0.7783 Acc: 0.7359
#
# Epoch 42/50
# ----------
# train Loss: 0.7075 Acc: 0.7465
# val Loss: 0.7824 Acc: 0.7339
#
# Epoch 43/50
# ----------
# train Loss: 0.7060 Acc: 0.7480
# val Loss: 0.7830 Acc: 0.7322
#
# Epoch 44/50
# ----------
# train Loss: 0.7066 Acc: 0.7468
# val Loss: 0.7816 Acc: 0.7311
#
# Epoch 45/50
# ----------
# train Loss: 0.7044 Acc: 0.7490
# val Loss: 0.7951 Acc: 0.7317
#
# Epoch 46/50
# ----------
# train Loss: 0.7078 Acc: 0.7453
# val Loss: 0.7864 Acc: 0.7308
#
# Epoch 47/50
# ----------
# train Loss: 0.7063 Acc: 0.7464
# val Loss: 0.7915 Acc: 0.7298
#
# Epoch 48/50
# ----------
# train Loss: 0.6974 Acc: 0.7485
# val Loss: 0.7790 Acc: 0.7374
#
# Epoch 49/50
# ----------
# train Loss: 0.7054 Acc: 0.7466
# val Loss: 0.7804 Acc: 0.7328
#
# Epoch 50/50
# ----------
# train Loss: 0.7059 Acc: 0.7464
# val Loss: 0.7938 Acc: 0.7292
#
# Training complete in 12m 41s
# Best val Acc: 0.7374
# Vision Transformer model saved as 'vit_cifar10.pth'
#
# Evaluating Vision Transformer on Test Set:
# Accuracy: 0.7372
# Precision: 0.7399
# Recall: 0.7372
# F1-Score: 0.7339
# Classification Report:
#               precision    recall  f1-score   support
#
#     airplane       0.73      0.77      0.75      1000
#   automobile       0.80      0.88      0.83      1000
#         bird       0.69      0.64      0.66      1000
#          cat       0.67      0.44      0.53      1000
#         deer       0.75      0.65      0.70      1000
#          dog       0.58      0.74      0.65      1000
#         frog       0.83      0.80      0.81      1000
#        horse       0.70      0.81      0.75      1000
#         ship       0.85      0.82      0.83      1000
#        truck       0.80      0.83      0.81      1000
#
#     accuracy                           0.74     10000
#    macro avg       0.74      0.74      0.73     10000
# weighted avg       0.74      0.74      0.73     10000
#
#
# Training Hybrid CNN-MLP Model...
# Epoch 1/50
# ----------
# train Loss: 1.8672 Acc: 0.3090
# val Loss: 1.7757 Acc: 0.3507
#
# Epoch 2/50
# ----------
# train Loss: 1.7082 Acc: 0.3680
# val Loss: 1.6499 Acc: 0.3981
#
# Epoch 3/50
# ----------
# train Loss: 1.6382 Acc: 0.3987
# val Loss: 1.6053 Acc: 0.4106
#
# Epoch 4/50
# ----------
# train Loss: 1.5935 Acc: 0.4150
# val Loss: 1.5981 Acc: 0.4175
#
# Epoch 5/50
# ----------
# train Loss: 1.5595 Acc: 0.4273
# val Loss: 1.5260 Acc: 0.4509
#
# Epoch 6/50
# ----------
# train Loss: 1.5351 Acc: 0.4383
# val Loss: 1.5090 Acc: 0.4414
#
# Epoch 7/50
# ----------
# train Loss: 1.5142 Acc: 0.4440
# val Loss: 1.5073 Acc: 0.4512
#
# Epoch 8/50
# ----------
# train Loss: 1.4993 Acc: 0.4509
# val Loss: 1.4814 Acc: 0.4618
#
# Epoch 9/50
# ----------
# train Loss: 1.4845 Acc: 0.4563
# val Loss: 1.4651 Acc: 0.4661
#
# Epoch 10/50
# ----------
# train Loss: 1.4628 Acc: 0.4661
# val Loss: 1.4535 Acc: 0.4746
#
# Epoch 11/50
# ----------
# train Loss: 1.4590 Acc: 0.4661
# val Loss: 1.4615 Acc: 0.4628
#
# Epoch 12/50
# ----------
# train Loss: 1.4448 Acc: 0.4726
# val Loss: 1.4117 Acc: 0.4839
#
# Epoch 13/50
# ----------
# train Loss: 1.4377 Acc: 0.4763
# val Loss: 1.4263 Acc: 0.4840
#
# Epoch 14/50
# ----------
# train Loss: 1.4243 Acc: 0.4807
# val Loss: 1.3945 Acc: 0.4916
#
# Epoch 15/50
# ----------
# train Loss: 1.4164 Acc: 0.4849
# val Loss: 1.4193 Acc: 0.4826
#
# Epoch 16/50
# ----------
# train Loss: 1.4147 Acc: 0.4858
# val Loss: 1.3799 Acc: 0.5011
#
# Epoch 17/50
# ----------
# train Loss: 1.3995 Acc: 0.4891
# val Loss: 1.4073 Acc: 0.4924
#
# Epoch 18/50
# ----------
# train Loss: 1.4006 Acc: 0.4908
# val Loss: 1.4044 Acc: 0.4880
#
# Epoch 19/50
# ----------
# train Loss: 1.3947 Acc: 0.4929
# val Loss: 1.3777 Acc: 0.4988
#
# Epoch 20/50
# ----------
# train Loss: 1.3821 Acc: 0.4970
# val Loss: 1.3835 Acc: 0.4961
#
# Epoch 21/50
# ----------
# train Loss: 1.3297 Acc: 0.5193
# val Loss: 1.3026 Acc: 0.5288
#
# Epoch 22/50
# ----------
# train Loss: 1.3163 Acc: 0.5206
# val Loss: 1.2983 Acc: 0.5335
#
# Epoch 23/50
# ----------
# train Loss: 1.3104 Acc: 0.5246
# val Loss: 1.2929 Acc: 0.5346
#
# Epoch 24/50
# ----------
# train Loss: 1.3077 Acc: 0.5250
# val Loss: 1.2901 Acc: 0.5377
#
# Epoch 25/50
# ----------
# train Loss: 1.3056 Acc: 0.5277
# val Loss: 1.2948 Acc: 0.5343
#
# Epoch 26/50
# ----------
# train Loss: 1.3018 Acc: 0.5265
# val Loss: 1.2849 Acc: 0.5378
#
# Epoch 27/50
# ----------
# train Loss: 1.2971 Acc: 0.5322
# val Loss: 1.2736 Acc: 0.5496
#
# Epoch 28/50
# ----------
# train Loss: 1.2975 Acc: 0.5302
# val Loss: 1.2752 Acc: 0.5397
#
# Epoch 29/50
# ----------
# train Loss: 1.2924 Acc: 0.5351
# val Loss: 1.2735 Acc: 0.5411
#
# Epoch 30/50
# ----------
# train Loss: 1.2950 Acc: 0.5292
# val Loss: 1.2752 Acc: 0.5431
#
# Epoch 31/50
# ----------
# train Loss: 1.2892 Acc: 0.5299
# val Loss: 1.2814 Acc: 0.5411
#
# Epoch 32/50
# ----------
# train Loss: 1.2853 Acc: 0.5351
# val Loss: 1.2709 Acc: 0.5434
#
# Epoch 33/50
# ----------
# train Loss: 1.2879 Acc: 0.5340
# val Loss: 1.2766 Acc: 0.5410
#
# Epoch 34/50
# ----------
# train Loss: 1.2859 Acc: 0.5336
# val Loss: 1.2746 Acc: 0.5456
#
# Epoch 35/50
# ----------
# train Loss: 1.2878 Acc: 0.5339
# val Loss: 1.2685 Acc: 0.5420
#
# Epoch 36/50
# ----------
# train Loss: 1.2809 Acc: 0.5385
# val Loss: 1.2705 Acc: 0.5451
#
# Epoch 37/50
# ----------
# train Loss: 1.2823 Acc: 0.5347
# val Loss: 1.2718 Acc: 0.5418
# Early stopping!
# Training complete in 5m 27s
# Best val Acc: 0.5496
# Hybrid CNN-MLP model saved as 'hybrid_cifar10.pth'
#
# Evaluating Hybrid CNN-MLP on Test Set:
# Accuracy: 0.5198
# Precision: 0.5234
# Recall: 0.5198
# F1-Score: 0.5135
# Classification Report:
#               precision    recall  f1-score   support
#
#     airplane       0.50      0.64      0.56      1000
#   automobile       0.60      0.58      0.59      1000
#         bird       0.43      0.41      0.42      1000
#          cat       0.38      0.18      0.25      1000
#         deer       0.52      0.48      0.50      1000
#          dog       0.39      0.60      0.48      1000
#         frog       0.55      0.67      0.61      1000
#        horse       0.59      0.54      0.56      1000
#         ship       0.64      0.57      0.60      1000
#        truck       0.64      0.52      0.57      1000
#
#     accuracy                           0.52     10000
#    macro avg       0.52      0.52      0.51     10000
# weighted avg       0.52      0.52      0.51     10000
#
#
# Training ResNet with Transfer Learning...
# Epoch 1/25
# ----------
# train Loss: 1.8623 Acc: 0.3350
# val Loss: 1.6984 Acc: 0.4062
#
# Epoch 2/25
# ----------
# train Loss: 1.7361 Acc: 0.3796
# val Loss: 1.6607 Acc: 0.4170
#
# Epoch 3/25
# ----------
# train Loss: 1.7081 Acc: 0.3929
# val Loss: 1.6493 Acc: 0.4142
#
# Epoch 4/25
# ----------
# train Loss: 1.6935 Acc: 0.4022
# val Loss: 1.6298 Acc: 0.4255
#
# Epoch 5/25
# ----------
# train Loss: 1.6773 Acc: 0.4037
# val Loss: 1.6103 Acc: 0.4320
#
# Epoch 6/25
# ----------
# train Loss: 1.6714 Acc: 0.4031
# val Loss: 1.5984 Acc: 0.4306
#
# Epoch 7/25
# ----------
# train Loss: 1.6734 Acc: 0.4073
# val Loss: 1.6030 Acc: 0.4314
#
# Epoch 8/25
# ----------
# train Loss: 1.6554 Acc: 0.4118
# val Loss: 1.6108 Acc: 0.4293
#
# Epoch 9/25
# ----------
# train Loss: 1.6522 Acc: 0.4118
# val Loss: 1.5868 Acc: 0.4371
#
# Epoch 10/25
# ----------
# train Loss: 1.6535 Acc: 0.4142
# val Loss: 1.5766 Acc: 0.4433
#
# Epoch 11/25
# ----------
# train Loss: 1.6151 Acc: 0.4265
# val Loss: 1.5665 Acc: 0.4433
#
# Epoch 12/25
# ----------
# train Loss: 1.6067 Acc: 0.4329
# val Loss: 1.5619 Acc: 0.4545
#
# Epoch 13/25
# ----------
# train Loss: 1.6090 Acc: 0.4288
# val Loss: 1.5520 Acc: 0.4505
#
# Epoch 14/25
# ----------
# train Loss: 1.5959 Acc: 0.4332
# val Loss: 1.5367 Acc: 0.4548
#
# Epoch 15/25
# ----------
# train Loss: 1.5976 Acc: 0.4316
# val Loss: 1.5611 Acc: 0.4440
#
# Epoch 16/25
# ----------
# train Loss: 1.5996 Acc: 0.4322
# val Loss: 1.5343 Acc: 0.4558
#
# Epoch 17/25
# ----------
# train Loss: 1.6026 Acc: 0.4294
# val Loss: 1.5410 Acc: 0.4577
#
# Epoch 18/25
# ----------
# train Loss: 1.5932 Acc: 0.4337
# val Loss: 1.5316 Acc: 0.4556
#
# Epoch 19/25
# ----------
# train Loss: 1.5945 Acc: 0.4343
# val Loss: 1.5301 Acc: 0.4583
#
# Epoch 20/25
# ----------
# train Loss: 1.5925 Acc: 0.4369
# val Loss: 1.5501 Acc: 0.4515
#
# Epoch 21/25
# ----------
# train Loss: 1.5825 Acc: 0.4409
# val Loss: 1.5309 Acc: 0.4653
#
# Epoch 22/25
# ----------
# train Loss: 1.5881 Acc: 0.4384
# val Loss: 1.5478 Acc: 0.4510
#
# Epoch 23/25
# ----------
# train Loss: 1.5861 Acc: 0.4372
# val Loss: 1.5403 Acc: 0.4547
#
# Epoch 24/25
# ----------
# train Loss: 1.5873 Acc: 0.4421
# val Loss: 1.5314 Acc: 0.4647
#
# Epoch 25/25
# ----------
# train Loss: 1.5878 Acc: 0.4387
# val Loss: 1.5279 Acc: 0.4581
#
# Training complete in 3m 58s
# Best val Acc: 0.4653
# ResNet model saved as 'resnet_cifar10.pth'
#
# Evaluating ResNet on Test Set:
# Accuracy: 0.4476
# Precision: 0.4521
# Recall: 0.4476
# F1-Score: 0.4447
# Classification Report:
#               precision    recall  f1-score   support
#
#     airplane       0.43      0.60      0.50      1000
#   automobile       0.52      0.50      0.51      1000
#         bird       0.39      0.37      0.38      1000
#          cat       0.37      0.34      0.36      1000
#         deer       0.44      0.46      0.45      1000
#          dog       0.40      0.41      0.40      1000
#         frog       0.47      0.60      0.53      1000
#        horse       0.51      0.42      0.46      1000
#         ship       0.46      0.43      0.44      1000
#        truck       0.54      0.33      0.41      1000
#
#     accuracy                           0.45     10000
#    macro avg       0.45      0.45      0.44     10000
# weighted avg       0.45      0.45      0.44     10000
#
#
# Performance Comparison:
#                 Model  Accuracy  Precision  Recall  F1-Score  \
# 0  Vision Transformer    0.7372   0.739854  0.7372  0.733873
# 1      Hybrid CNN-MLP    0.5198   0.523364  0.5198  0.513520
# 2              ResNet    0.4476   0.452083  0.4476  0.444681
#
#    Training Time (s)
# 0         760.605812
# 1         327.444978
# 2         237.610090
# Training Curves for Vision Transformer:
# Training Curves for Hybrid CNN-MLP:
# Training Curves for ResNet:
# Model comparison metrics saved as 'model_comparison.csv'

# %%
# -----------------------------
# 13. Deployment and Result Visualization
# -----------------------------

# Function to visualize predictions
def visualize_predictions(model, dataloader, classes, num_images=16):
    model.eval()
    images_shown = 0
    plt.figure(figsize=(12,12))
    
    with torch.no_grad():
        for inputs, labels in dataloader:
            inputs = inputs.to(device)
            labels = labels.to(device)
            
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            
            for i in range(inputs.size(0)):
                if images_shown == num_images:
                    plt.show()
                    return
                images_shown +=1
                
                ax = plt.subplot(int(np.sqrt(num_images))+1, int(np.sqrt(num_images))+1, images_shown)
                img = inputs[i].cpu().numpy()
                # Unnormalize
                img = img * np.array([0.2023, 0.1994, 0.2010]).reshape(3,1,1) + np.array([0.4914, 0.4822, 0.4465]).reshape(3,1,1)
                img = np.clip(img, 0, 1)
                img = np.transpose(img, (1, 2, 0))
                plt.imshow(img)
                title_color = 'green' if preds[i] == labels[i] else 'red'
                plt.title(f'Pred: {classes[preds[i]]}\nTrue: {classes[labels[i]]}', color=title_color)
                plt.axis('off')
    plt.show()

# Visualize predictions for ViT
print("\nVision Transformer Predictions:")
visualize_predictions(vit_trained, test_loader, test_dataset.classes)

# Visualize predictions for Hybrid Model
print("\nHybrid CNN-MLP Predictions:")
visualize_predictions(hybrid_trained, test_loader, test_dataset.classes)

# Visualize predictions for ResNet
print("\nResNet Predictions:")
visualize_predictions(resnet_trained, test_loader, test_dataset.classes)
# Out:
# Vision Transformer Predictions:
# Hybrid CNN-MLP Predictions:
# ResNet Predictions:
